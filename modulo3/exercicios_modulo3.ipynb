# %% [markdown]
# # Lista de Exercícios — Módulo 3
#
# **Curso:** Python para Ciência de Dados
# **Disciplina:** Ciência de Dados (T326) — UNIFOR
#
# Resolva cada exercício na célula indicada. O gabarito está no arquivo `gabarito_modulo3.ipynb`.

# %% [markdown]
# ---
#
# ### Exercício 1 – Tipos de Gráficos
#
# Associe cada situação ao tipo de gráfico mais adequado:
#
# a) Mostrar a distribuição de idades de uma turma
#
# b) Comparar o salário médio entre cidades
#
# c) Mostrar a relação entre altura e peso
#
# d) Mostrar a evolução das vendas ao longo dos meses
#
# e) Mostrar a proporção de gastos por categoria
#
#
# Tipos de gráficos:
#
# - Histograma
#
# - Gráfico de Barras
#
# - Gráfico de Dispersão
#
# - Gráfico de Linhas
#
# - Gráfico de Pizza

# %% [markdown]
# ---
#
# ### Exercício 2 – Matplotlib Básico
#
# Crie um gráfico de linha com os seguintes dados:

# %%
meses = [1,2,3,4,5,6]
vendas = [100, 120, 150, 130, 170, 200]

# Sua resposta abaixo:

# %% [markdown]
# O gráfico deve:
#
# - Ter título
# - Ter nome nos eixos
# - Mostrar marcadores nos pontos

# %% [markdown]
# ---
#
# ### Exercício 3 – Histograma
#
# Crie um histograma para o conjunto de dados:

# %%
idades = [18,19,20,21,22,22,23,24,25,25,26,27,28,30,32,35]

# Sua resposta abaixo:

# %% [markdown]
# Perguntas:
#
# 1. Qual é a faixa de idade mais frequente?
# 2. O conjunto parece ter distribuição uniforme?

# %% [markdown]
# ---
#
# ### Exercício 4 – Scatter Plot
#
# Crie um gráfico de dispersão com os dados:

# %%
horas_estudo = [1,2,3,4,5,6,7,8]
notas = [4,5,5,6,7,8,9,9]

# Sua resposta abaixo:

# %% [markdown]
# Perguntas:
#
# 1. Existe relação entre horas de estudo e nota?
# 2. Essa relação parece positiva ou negativa?

# %% [markdown]
# ---
#
# ### Exercício 5 – Gráfico de Barras com Seaborn
#
# Faça um gráfico de barras mostrando a média de vendas por cidade usando Seaborn.

# %%
import pandas as pd

dados = {
    "Cidade": ["Fortaleza", "Recife", "Salvador", "Fortaleza", "Recife", "Salvador"],
    "Vendas": [200, 150, 180, 220, 170, 190]
}

df = pd.DataFrame(dados)

# Sua resposta abaixo:

# %% [markdown]
# ---
#
# ### Exercício 6 – Boxplot
#
# Crie um boxplot para o conjunto de salários:

# %%
salarios = [2000, 2200, 2500, 2700, 3000, 3200, 3500, 4000, 4500, 10000]

# Sua resposta abaixo:

# %% [markdown]
# Perguntas:
#
# 1. Existe outlier?
# 2. Onde está a mediana aproximadamente?
# 3. O que o boxplot mostra sobre a distribuição dos salários?

# %% [markdown]
# ---
#
# ### Exercício 7 – Personalização de Gráficos
#
# Crie um gráfico de linha com:

# %%
anos = [2018,2019,2020,2021,2022,2023]
lucro = [10, 15, 8, 20, 25, 30]

# Sua resposta abaixo:

# %% [markdown]
# O gráfico deve:
#
# - Ter título
# - Ter labels
# - Ter grid
# - Ter linha vermelha
# - Ter marcadores
