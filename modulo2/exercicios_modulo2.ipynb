# %% [markdown]
# # Lista de Exercícios — Módulo 2
#
# **Curso:** Python para Ciência de Dados
# **Disciplina:** Ciência de Dados (T326) — UNIFOR
#
# Resolva cada exercício na célula indicada. O gabarito está no arquivo `gabarito_modulo2.ipynb`.

# %% [markdown]
# ---
#
# ### Exercício 1 — Criando DataFrame
#
# Crie um DataFrame com as seguintes colunas:
#
# - Nome
# - Idade
# - Cidade
# - Salario
#
# Adicione pelo menos 5 pessoas e exiba o DataFrame.

# %%
# Exercício 1

# %% [markdown]
# ---
#
# ### Exercício 2 — Inspeção de Dados
#
# Dado o DataFrame criado no exercício anterior, exiba:
#
# 1. As 5 primeiras linhas
# 2. As 5 últimas linhas
# 3. As informações do dataset
# 4. A quantidade de linhas e colunas

# %%
# Exercício 2

# %% [markdown]
# ---
#
# ### Exercício 3 — Valores Nulos
#
# Crie um novo DataFrame contendo alguns valores nulos nas colunas Idade e Salario.
#
# Depois:
# 1. Verifique quantos valores nulos existem
# 2. Preencha os valores nulos com a média da coluna
# 3. Exiba o DataFrame atualizado

# %%
# Exercício 3

# %% [markdown]
# ---
#
# ### Exercício 4 — Remover Duplicados
#
# Crie um DataFrame que possua linhas duplicadas.
#
# Depois:
# 1. Exiba o DataFrame
# 2. Remova as linhas duplicadas
# 3. Exiba o DataFrame novamente

# %%
# Exercício 4

# %% [markdown]
# ---
#
# ### Exercício 5 — Filtros
#
# Utilizando um DataFrame com as colunas Nome, Idade, Cidade e Salario:
#
# 1. Exiba apenas pessoas com idade maior que 30
# 2. Exiba apenas pessoas que moram em Fortaleza
# 3. Exiba apenas pessoas com salário maior que 3000

# %%
# Exercício 5

# %% [markdown]
# ---
#
# ### Exercício 6 — Estatística Descritiva
#
# Utilizando a coluna Salario de um DataFrame, calcule:
#
# - Média
# - Mediana
# - Moda
# - Maior salário
# - Menor salário

# %%
# Exercício 6

# %% [markdown]
# ---
#
# ### Exercício 7 — Ordenação
#
# Ordene o DataFrame:
#
# 1. Por Idade (crescente)
# 2. Por Salario (decrescente)

# %%
# Exercício 7

# %% [markdown]
# ---
#
# ### Exercício 8 — Desafio Final
#
# Crie um DataFrame com informações de alunos contendo:
#
# - Nome
# - Curso
# - Nota
# - Frequencia
#
# Depois responda:
#
# 1. Qual a média das notas?
# 2. Qual o aluno com maior nota?
# 3. Exiba apenas alunos com nota maior que 7
# 4. Ordene os alunos pela nota

# %%
# Exercício 8
