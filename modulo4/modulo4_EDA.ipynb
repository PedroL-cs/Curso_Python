# %% [markdown]
# # Análise Exploratória de Dados – Gorjetas
#
# ## Contexto
#
# Este conjunto de dados contém informações sobre contas de um restaurante, incluindo valor total da conta, gorjeta, dia da semana, horário e tamanho do grupo.
#
# O objetivo desta análise é entender o comportamento dos clientes em relação às gorjetas e identificar padrões que possam gerar insights úteis para o negócio.
#
# ---
#
# ## Objetivos da análise
#
# * Entender como as gorjetas estão distribuídas
# * Verificar relação entre valor da conta e gorjeta
# * Analisar influência de fatores como dia, horário e tamanho do grupo
# * Identificar padrões relevantes para tomada de decisão
#
# ---
#
# ## Perguntas norteadoras
#
# * Clientes dão gorjetas proporcionalmente ao valor da conta?
# * Existem dias ou horários com gorjetas maiores?
# * O tamanho do grupo influencia o valor da gorjeta?
# * Existem outliers ou comportamentos fora do padrão?

# %% [markdown]
# ---
#
# ## 1. Importação das Bibliotecas
#
# Para realizar a análise de dados, precisamos importar algumas bibliotecas do Python:
#
# - pandas: manipulação e análise de dados
# - matplotlib: criação de gráficos
# - seaborn: visualização de dados mais avançada
#
# Essas bibliotecas são amplamente utilizadas em projetos de análise de dados e ciência de dados.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
#
# ## 2. Carregamento do Dataset
#
# Nesta etapa vamos carregar o conjunto de dados que será analisado.
# O dataset utilizado se chama "Tips" e contém informações sobre contas
# de um restaurante, incluindo valor da conta, gorjeta, dia da semana,
# período (almoço ou jantar), sexo do cliente e número de pessoas na mesa.
#
# Após carregar os dados, vamos visualizar as primeiras linhas do dataset
# para entender como os dados estão organizados.

# %%
tips = sns.load_dataset("tips")
tips.head()

# %% [markdown]
# ---
#
# ## 3. Inspeção Inicial dos Dados
#
# Antes de iniciar a análise, é importante entender a estrutura do dataset.
# Vamos verificar:
#
# - Quantas linhas e colunas existem
# - Tipos de dados
# - Estatísticas básicas
# - Valores nulos
#
# Isso ajuda a identificar possíveis problemas nos dados.

# %%
tips.info()
tips.describe()
tips.isnull().sum()

# %% [markdown]
# ### Observações
#
# A partir das informações acima, podemos observar a estrutura do dataset,
# os tipos de dados presentes e algumas estatísticas iniciais como média,
# mínimo, máximo e desvio padrão.
#
# Também verificamos se existem valores nulos que precisariam ser tratados
# antes da análise.

# %% [markdown]
# ---
#
# ## 4. Análise Estatística
#
# Agora vamos calcular algumas estatísticas importantes para entender melhor
# o comportamento das gorjetas e das contas do restaurante.
#
# Vamos analisar:
# - Média das gorjetas
# - Média das contas
# - Gorjeta média por dia da semana
# - Gorjeta média por período (almoço ou jantar)
# - Gorjeta média por número de pessoas

# %%
# Média das gorjetas
tips["tip"].mean()

# Média da conta
tips["total_bill"].mean()

# Gorjeta média por dia
tips.groupby("day")["tip"].mean()

# Gorjeta média por período
tips.groupby("time")["tip"].mean()

# Gorjeta média por número de pessoas
tips.groupby("size")["tip"].mean()

# %% [markdown]
# ### Interpretação
#
# * A média das gorjetas indica o comportamento geral dos clientes em relação ao valor pago como gratificação.
# * Observa-se que a média das gorjetas varia entre os dias da semana, sugerindo que o contexto (ex: fim de semana) pode influenciar esse valor.
# * Diferenças entre almoço e jantar indicam que o período do dia pode impactar o valor das gorjetas.
# * Mesas com mais pessoas tendem a apresentar gorjetas maiores, o que pode estar relacionado ao aumento do valor total da conta.
#
# Essas análises iniciais ajudam a direcionar as próximas explorações visuais.

# %% [markdown]
# ---
#
# ## 5. Visualizações de Dados
#
# A visualização de dados é uma etapa muito importante da análise exploratória,
# pois permite identificar padrões, tendências e possíveis outliers de forma
# mais clara através de gráficos.
#
# A seguir, serão apresentados alguns gráficos para analisar o comportamento
# das contas e gorjetas.

# %% [markdown]
# ### Distribuição do valor das contas
#
# **Objetivo:** Analisar como os valores das contas estão distribuídos.
#
# **Pergunta:** A maioria das contas está concentrada em valores baixos ou existem muitas contas altas?

# %%
plt.hist(tips["total_bill"])
plt.title("Distribuição do Valor das Contas")
plt.xlabel("Valor da Conta")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# **Interpretação:**
#
# A maior parte das contas está concentrada em valores mais baixos, com poucos casos de contas muito altas.
#
# Isso indica um padrão de consumo moderado, com presença de outliers.
#
# ---

# %% [markdown]
# ### Distribuição das gorjetas
#
# **Objetivo:** Entender o comportamento dos valores de gorjeta.
#
# **Pergunta:** As gorjetas seguem um padrão concentrado ou são muito variadas?

# %%
plt.hist(tips["tip"])
plt.title("Distribuição das Gorjetas")
plt.show()

# %% [markdown]
# **Interpretação:**
#
# As gorjetas apresentam concentração em valores menores, com poucos casos mais elevados.
#
# Isso sugere um comportamento relativamente consistente entre os clientes.
#
# ---

# %% [markdown]
# ### Relação entre valor da conta e gorjeta
#
# **Objetivo:** Verificar se existe relação entre o valor da conta e o valor da gorjeta.
#
# **Pergunta:** Clientes dão gorjetas proporcionalmente ao valor da conta?

# %%
plt.scatter(tips["total_bill"], tips["tip"])
plt.xlabel("Conta")
plt.ylabel("Gorjeta")
plt.title("Conta vs Gorjeta")
plt.show()

# %% [markdown]
# **Interpretação:**
#
# Observa-se uma relação positiva entre o valor da conta e a gorjeta, indicando que, em geral, quanto maior a conta, maior a gorjeta.
#
# Isso sugere que os clientes tendem a manter uma proporção ao definir a gorjeta.
#
# ---

# %% [markdown]
# ### Distribuição de gorjetas por dia da semana
#
# **Objetivo:** Comparar como as gorjetas variam entre os dias.
#
# **Pergunta:** Existem dias com maior variabilidade ou valores mais altos de gorjeta?

# %%
sns.boxplot(x="day", y="tip", data=tips)
plt.title("Gorjeta por Dia da Semana")
plt.show()

# %% [markdown]
# **Interpretação:**
#
# Alguns dias apresentam maior dispersão nos valores de gorjeta, indicando maior variabilidade no comportamento dos clientes.
#
# Isso pode estar relacionado a diferenças no perfil de consumo ao longo da semana.
#
# ---

# %% [markdown]
# ### Média de gorjeta por categoria
#
# **Objetivo:** Comparar o valor médio das gorjetas entre diferentes grupos.
#
# **Pergunta:** Existem diferenças relevantes entre categorias como dia, período ou sexo?

# %%
sns.barplot(x="day", y="tip", data=tips)
plt.title("Média de Gorjeta por Dia")
plt.show()

# %% [markdown]
# **Interpretação:**
#
# Observam-se diferenças nas médias entre as categorias analisadas, indicando que fatores contextuais podem influenciar o valor da gorjeta.
#
# Essas diferenças ajudam a identificar padrões de comportamento dos clientes.

# %% [markdown]
# ---
#
# ## 6. Insights
#
# Após a análise exploratória e a visualização dos dados, foi possível identificar
# alguns padrões importantes no comportamento das contas e gorjetas do restaurante.
#
# ### Distribuição das Contas
# Observando o histograma do valor das contas, percebemos que a maioria das contas
# está concentrada em valores mais baixos, enquanto poucas contas possuem valores
# muito altos, caracterizando possíveis outliers.
#
# ### Distribuição das Gorjetas
# A distribuição das gorjetas segue um padrão semelhante ao das contas, com a maioria
# das gorjetas em valores menores e poucas gorjetas muito altas.
#
# ### Relação entre Conta e Gorjeta
# No gráfico de dispersão (scatter plot), foi possível observar uma relação positiva
# entre o valor da conta e o valor da gorjeta. Isso indica que, em geral, quanto maior
# a conta, maior a gorjeta deixada pelo cliente.
#
# ### Gorjeta por Dia da Semana
# Através do boxplot e do barplot por dia da semana, observamos que alguns dias
# apresentam maior média de gorjetas, indicando que o comportamento dos clientes
# pode variar dependendo do dia.
#
# ### Gorjeta por Período (Almoço ou Jantar)
# A análise mostrou que o período do jantar geralmente apresenta gorjetas maiores
# do que o período do almoço, possivelmente porque as contas do jantar costumam ser maiores.
#
# ### Gorjeta por Sexo
# Comparando as gorjetas por sexo, observamos pequenas diferenças nos valores médios,
# mas sem uma diferença muito significativa entre homens e mulheres.
#
# ### Correlação entre Variáveis
# A matriz de correlação mostrou que a variável que possui maior relação com a gorjeta
# é o valor da conta total, reforçando a ideia de que a gorjeta está diretamente
# relacionada ao valor gasto pelo cliente.
#
# ### Insight Geral
# De forma geral, o fator que mais influencia o valor da gorjeta é o valor da conta,
# enquanto fatores como dia da semana, período e número de pessoas também possuem
# influência, mas em menor escala.

# %% [markdown]
# ---
#
# ## Conclusão
#
# A análise exploratória permitiu identificar padrões relevantes no comportamento das gorjetas.
#
# Os resultados indicam que:
#
# * Existe uma relação direta entre o valor da conta e a gorjeta
# * Fatores como dia da semana e período influenciam o valor das gorjetas
# * O tamanho do grupo também impacta o valor final
#
# Do ponto de vista do negócio, esses insights podem ajudar na tomada de decisões, como alocação de equipe em dias mais movimentados e estratégias para melhorar a experiência do cliente.
#
# Como próximos passos, análises mais aprofundadas poderiam explorar a proporção da gorjeta em relação à conta e segmentações mais detalhadas dos clientes.
